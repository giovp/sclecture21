# %%
import pandas as pd
import numpy as np
import imageio
import seaborn as sns
import matplotlib.pyplot as plt
import scanpy as sc

# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

# %%
adata = sc.read(
    "/home/icb/oksana.bilous/sc_tumor_immune_atlas/immune_atlas_full_adata.h5ad"
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 317111 × 87659
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'patient', 'percent.mt', 'gender', 'source', 'cancer_type', 'cluster_kmeans_k6', 'cell_type', 'cell_type_annotation', 'cancer_type_annotation'
#     var: 'features'
#     uns: 'cancer_type_annotation_colors'
#     obsm: 'X_umap'

# %%
sc.pl.umap(adata, color=["cancer_type_annotation"])

# %%
adata.obs.cell_type = pd.Categorical(adata.obs.cell_type)

# %%
sc.pl.umap(
    adata[adata.obs.cancer_type_annotation == "Pancreatic Ductal Adenocarcinomas"],
    color=["cell_type_annotation"],
)
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
adata[adata.obs.cancer_type_annotation == "Pancreatic Ductal Adenocarcinomas"].shape
# Out:
# (10623, 87659)
